# %%
print("Chai aur code")
print("phela conda,jupyter setup")
# Out:
# Chai aur code
# phela conda,jupyter setup

# %% [markdown]
# ### Chai aur Pyhton
# This core pyhton learning
#
# -----

# %% [markdown]
# for i in range(7):
#     print(i, end="_")
